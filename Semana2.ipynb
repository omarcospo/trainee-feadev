# %% [markdown]
# ## Exercício 1 ##
#
# Suponha que você está estudando história e quer saber as diferenças entra as datas ao longo tempo, a fim de entender o quão rápido aconteceu o fato
# histórico. Assim, você busca uma base de dados sobre a Revolução Russa.

# %%
import pandas as pd

# Criação da tabela com eventos e datas
data = {
    "Evento": [
        "Domingo Sangrento",
        "Revolução de Fevereiro",
        "Abdicação do Czar Nicolau II",
        "Revolução de Outubro",
        "Tratado de Brest-Litovsk",
        "Início da Guerra Civil Russa",
        "Fundação da União Soviética",
    ],
    "Data": [
        "1905-01-22",
        "1917-03-08",
        "1917-03-15",
        "1917-11-07",
        "1918-03-03",
        "1918-06-01",
        "1922-12-30",
    ],
}

df = pd.DataFrame(data)

# Convertendo a coluna 'Data' para datetime
df["Data"] = pd.to_datetime(df["Data"])

# Define a data referência
data_referencia = pd.Timestamp("1905-01-22")

# Calculando a diferença de dias entre os eventos
df["Diferença (dias)"] = (df["Data"] - data_referencia).dt.days

# Formatando coluna data
df["Data"] = df["Data"].dt.strftime("%d/%m/%Y")

# Exibindo os resultados
print(df)
# Out:
#                          Evento        Data  Diferença (dias)
# 0             Domingo Sangrento  22/01/1905                 0
# 1        Revolução de Fevereiro  08/03/1917              4428
# 2  Abdicação do Czar Nicolau II  15/03/1917              4435
# 3          Revolução de Outubro  07/11/1917              4672
# 4      Tratado de Brest-Litovsk  03/03/1918              4788
# 5  Início da Guerra Civil Russa  01/06/1918              4878
# 6   Fundação da União Soviética  30/12/1922              6551

# %% [markdown]
# ## Exercício 2 ##
#
# Você é um consultor de empresas e tem uma base de dados com vários dias e quantidades vendidas. Afim de maximizar os lucros, você entende que é melhor sempre abrir a loja num dado dia da semana que houver o maior faturamento por mais tempo.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Dados fornecidos
dados_vendas = {
    "Data": [
        "2024-01-01",
        "2024-01-02",
        "2024-01-03",
        "2024-01-04",
        "2024-01-05",
        "2024-01-06",
        "2024-01-07",
        "2024-01-08",
        "2024-01-09",
        "2024-01-10",
        "2024-02-01",
        "2024-02-02",
        "2024-02-03",
        "2024-02-04",
        "2024-02-05",
        "2024-02-06",
        "2024-02-07",
        "2024-02-08",
        "2024-02-09",
        "2024-02-10",
        "2024-03-01",
        "2024-03-02",
        "2024-03-03",
        "2024-03-04",
        "2024-03-05",
        "2024-03-06",
        "2024-03-07",
        "2024-03-08",
        "2024-03-09",
        "2024-03-10",
    ],
    "Valor": [
        150.25,
        89.99,
        120.50,
        75.00,
        200.75,
        145.00,
        95.25,
        220.40,
        185.90,
        300.00,
        50.00,
        175.75,
        110.00,
        130.50,
        90.25,
        210.80,
        175.40,
        95.00,
        120.75,
        150.00,
        80.25,
        200.50,
        170.00,
        100.75,
        130.00,
        220.00,
        195.50,
        85.75,
        140.00,
        250.75,
    ],
}

# Criando o DataFrame
df_vendas = pd.DataFrame(dados_vendas)

# Convertendo coluna 'Data' para datetime
df_vendas["Data"] = pd.to_datetime(df_vendas["Data"])

# Adicionando coluna com dias da semana
df_vendas["Dia da semana"] = df_vendas["Data"].dt.day_name()

# Agrupamento por semana
df_semanas = df_vendas.groupby(df_vendas["Dia da semana"])["Valor"].sum()

# Gráfico
plt.figure(figsize=(10, 5))
df_semanas.plot(kind="bar")
plt.xlabel("Dia da semana")
plt.ylabel("Valor")
plt.title("Vendas por dia da semana durante o período")
plt.xticks(rotation=45)
plt.show()

# Exibindo o DataFrame
print(df_semanas)
# Out:
# Dia da semana
# Friday       663.25
# Monday       561.65
# Saturday     745.50
# Sunday       646.50
# Thursday     415.50
# Tuesday      616.69
# Wednesday    815.90
# Name: Valor, dtype: float64

# %% [markdown]
# Portanto, o dia que mais fatura é quarta com o valor de 815.90 será o dia que ficará funcionando por mais tempo!
